# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# u can use keyword **marker** to emphasize each point

# %%
y_points = np.array([3,8,6,10])

plt.plot(y_points , marker='*')

plt.show()

# %% [markdown]
# **Format String fmt**
#
# You can also use the shortcut string notation parameter to specify the marker
#
# This parameter is also called fmt, and is written with this syntax:
#
# ``marker|line|color``

# %%
plt.plot(y_points,'*--g')

# %% [markdown]
# **Marker Size**
#
# You can use the keyword argument **markersize** or the shorter version, **ms** to set the size of the markers

# %%
plt.plot(y_points , '*:b' , ms=8)

plt.show()

# %% [markdown]
# **Marker Color**
#
# You can use the keyword argument markeredgecolor or the shorter **mec** to set the color of the edge of the markers

# %%
plt.plot(y_points , '*:b' , ms=20 , mec = 'r')

plt.show()

# %% [markdown]
# **Marker Face Color**
#
# You can use the keyword argument markerfacecolor or the shorter mfc to set the color inside the edge of the markers
#
# * u can use Hexadecimal values

# %%
plt.plot(y_points , '*:b' , ms=20 , mec = 'r' , mfc = 'g')

plt.show()

# %%
plt.plot(y_points , '*:b' , ms=20 , mec = '#4CAF50' , mfc = '#4CAF50')

plt.show()
