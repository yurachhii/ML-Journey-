# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# **Labels**

# %% [markdown]
# u will be using **x_labels** and **y_labels** funcs to set a lebel for the x-axis and y-axis

# %% [markdown]
# **Titles**
#
# u will be using **title()** func to create a title for the plot

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.title("Sport Watch Data")

plt.show()

# %% [markdown]
# **Position of a title**
#
# You can use the loc parameter in title() to position the title

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title('Sport Watch Data',loc = 'left')

plt.show()

# %% [markdown]
# **Grid**
#
# u can use **grid()** function to grid lines
#
# * u can specify if it's x or y grid
#
# * u can set the line properties of the grid like this: grid(color = 'color', linestyle = 'linestyle', linewidth = number)

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title('Sport Watch Data',loc = 'left')
plt.grid()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title('Sport Watch Data',loc = 'left')
plt.grid(axis = 'x')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title('Sport Watch Data',loc = 'left')
plt.grid(axis = 'y')
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x,y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.title('Sport Watch Data',loc = 'left')
plt.grid(color= 'r' , ls = ':' , lw = 1)
plt.show()
